-- %% [markdown]
-- # Process the Customers Data
--
-- - 1. Ingest the data into the data lakehouse - bronze_customers
-- - 2. Perform data quality checks and transform the data as required - silver_customer_clean
-- - 3. Apply changes to the Customers data - silver_customers

-- %% [markdown]
-- ## 1. Ingest the data into the data lakehouse - bronze_customers
-- ![CircuitBox_Process Customers Data.png](./CircuitBox_Process Customers Data.png "CircuitBox_Process Customers Data.png")

-- %%
CREATE OR REFRESH STREAMING TABLE bronze_customers
COMMENT 'Raw customers data ingested from the source system operational data'
TBLPROPERTIES (
    'quality' =  'bronze'
)
AS
SELECT *,
    _metadata.file_path AS input_file_path,
    current_timestamp() AS ingestion_timestamp
FROM cloud_files(
    '/Volumes/circuitbox/landing/operational_data/customers/',
    'json',
    map(
      'cloudFiles.inferColumnTypes', 'true'  
    )
)

-- %% [markdown]
-- 2. Perform data quality checks and transform the data as required - silver_customers_clean
-- ![CircuitBox_Process Customers Data_silverClean.png](./CircuitBox_Process Customers Data_silverClean.png "CircuitBox_Process Customers Data_silverClean.png")

-- %%
CREATE OR REFRESH STREAMING TABLE silver_customers_clean (
    CONSTRAINT valid_customer_id 
        EXPECT (customer_id IS NOT NULL) ON VIOLATION FAIL UPDATE,
    CONSTRAINT valid_customer_name
        EXPECT (customer_name IS NOT NULL) ON VIOLATION DROP ROW,
    CONSTRAINT valid_telephone_number
        EXPECT (LENGTH(telephone) >= 10),
    CONSTRAINT valid_email
        EXPECT (email IS NOT NULL),
    CONSTRAINT valid_date_of_birth
        EXPECT (date_of_birth >= '1920-01-01')

)
COMMENT 'Cleaned customers data'
TBLPROPERTIES (
    'quality' = 'silver'
)
AS
SELECT customer_id,
       customer_name,
       CAST(date_of_birth AS DATE) AS date_of_birth,
       telephone,
       email,
       CAST(created_date AS DATE) AS created_date
    FROM STREAM(LIVE.bronze_customers);

-- %% [markdown]
-- 3. Apply Changes to the Customers Data - silver_customers
-- ![CircuitBox_Process Customer Data Silver_Customer.png](./CircuitBox_Process Customer Data Silver_Customer.png "CircuitBox_Process Customer Data Silver_Customer.png")

-- %%
CREATE OR REFRESH STREAMING TABLE silver_customers
    COMMENT 'SCD Type 1 customers data'
    TBLPROPERTIES (
    'quality' = 'silver'
    );

-- %%
APPLY CHANGES INTO LIVE.silver_customers
FROM STREAM(LIVE.silver_customers_clean)
KEYS(customer_id)
SEQUENCE BY created_date
STORED AS SCD TYPE 1; -- Optional. Type 1 is the default value
